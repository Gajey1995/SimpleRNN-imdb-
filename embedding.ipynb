# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\Aaryan\anaconda3\envs\MYRNNEnv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import keras
#
# File d:\GenerativeAISample\annclassification\MYANNEnv\Lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File d:\GenerativeAISample\annclassification\MYANNEnv\Lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File d:\GenerativeAISample\annclassification\MYANNEnv\Lib\site-packages\keras\__internal__\backend\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# File d:\GenerativeAISample\annclassification\MYANNEnv\Lib\site-packages\keras\src\__init__.py:21
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 21 from keras.src import applications
#      22 from keras.src import distribute
#      23 from keras.src import models
#
# File d:\GenerativeAISample\annclassification\MYANNEnv\Lib\site-packages\keras\src\applications\__init__.py:18
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from keras.src.applications.convnext import ConvNeXtBase
#      19 from keras.src.applications.convnext import ConvNeXtLarge
#      20 from keras.src.applications.convnext import ConvNeXtSmall
#
# File d:\GenerativeAISample\annclassification\MYANNEnv\Lib\site-packages\keras\src\applications\convnext.py:26
#      17 """ConvNeXt models for Keras.
#      18
#      19 References:
#    (...)     22   (CVPR 2022)
#      23 """
#      25 import numpy as np
# ---> 26 import tensorflow.compat.v2 as tf
#      28 from keras.src import backend
#      29 from keras.src import initializers
#
# ModuleNotFoundError: No module named 'tensorflow.compat'

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[6933, 1782, 9538, 7060],
#  [6933, 1782, 9538, 4375],
#  [6933, 7025, 9538, 4994],
#  [2067, 7299, 1502, 9008, 3863],
#  [2067, 7299, 1502, 9008, 5967],
#  [896, 6933, 8615, 9538, 2680],
#  [8332, 7627, 1622, 9008]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 6933 1782 9538 7060]
#  [   0    0    0    0 6933 1782 9538 4375]
#  [   0    0    0    0 6933 7025 9538 4994]
#  [   0    0    0 2067 7299 1502 9008 3863]
#  [   0    0    0 2067 7299 1502 9008 5967]
#  [   0    0    0  896 6933 8615 9538 2680]
#  [   0    0    0    0 8332 7627 1622 9008]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\Aaryan\anaconda3\envs\MYRNNEnv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Aaryan\anaconda3\envs\MYRNNEnv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 132ms/step
# array([[[-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [ 0.02947653,  0.02852466,  0.02064506, -0.00574272,
#           0.04779477, -0.04508482, -0.0359484 , -0.03446455,
#           0.04430174, -0.01418214],
#         [ 0.04513296, -0.00621722,  0.00513292, -0.04443559,
#          -0.04414323,  0.00077445, -0.00539219,  0.04589731,
#          -0.00551224, -0.03545781],
#         [ 0.01732167,  0.01659891, -0.03761937, -0.00788709,
#          -0.0014287 ,  0.01733841, -0.03760829, -0.00587931,
#          -0.03877031, -0.03142788],
#         [ 0.02062107, -0.00170489, -0.00292142, -0.02680603,
#          -0.02570215, -0.01528143, -0.01510052, -0.01754496,
#           0.02350179, -0.00055983]],
#
#        [[-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [ 0.02947653,  0.02852466,  0.02064506, -0.00574272,
#           0.04779477, -0.04508482, -0.0359484 , -0.03446455,
#           0.04430174, -0.01418214],
#         [ 0.04513296, -0.00621722,  0.00513292, -0.04443559,
#          -0.04414323,  0.00077445, -0.00539219,  0.04589731,
#          -0.00551224, -0.03545781],
#         [ 0.01732167,  0.01659891, -0.03761937, -0.00788709,
#          -0.0014287 ,  0.01733841, -0.03760829, -0.00587931,
#          -0.03877031, -0.03142788],
#         [-0.01436799, -0.00142193, -0.04405944, -0.04770375,
#          -0.03519635,  0.01733189, -0.01797847, -0.01438361,
#          -0.02759359, -0.0304828 ]],
#
#        [[-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [ 0.02947653,  0.02852466,  0.02064506, -0.00574272,
#           0.04779477, -0.04508482, -0.0359484 , -0.03446455,
#           0.04430174, -0.01418214],
#         [ 0.00026327, -0.03280364, -0.03713693, -0.01096714,
#          -0.01673403,  0.03278316, -0.02782023, -0.04698538,
#          -0.00580243,  0.03162003],
#         [ 0.01732167,  0.01659891, -0.03761937, -0.00788709,
#          -0.0014287 ,  0.01733841, -0.03760829, -0.00587931,
#          -0.03877031, -0.03142788],
#         [ 0.01961436, -0.04390315, -0.00326119,  0.04556853,
#          -0.01661931, -0.00177096,  0.04025357,  0.02525676,
#          -0.02996732, -0.03152099]],
#
#        [[-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.0126553 ,  0.01534278, -0.03871063, -0.04987437,
#           0.02977861, -0.03553314, -0.00416569, -0.01277151,
#          -0.04292266,  0.04102322],
#         [-0.03033017,  0.0220539 ,  0.04938984, -0.01309539,
#           0.00350443,  0.01133143, -0.04417115, -0.00655508,
#           0.00018213, -0.02144477],
#         [ 0.01389608,  0.01005043, -0.01167576, -0.03750848,
#           0.02761997,  0.01979787, -0.01873717,  0.00797687,
#           0.030223  , -0.03977693],
#         [-0.00396502,  0.00770275,  0.00732481, -0.01204047,
#          -0.04001433,  0.00302528, -0.0175334 ,  0.03143207,
#           0.00956482, -0.04212653],
#         [-0.04604594, -0.04596723, -0.00512708, -0.02106848,
#           0.0315557 , -0.03425296,  0.01660458,  0.01669029,
#           0.0146543 ,  0.04543697]],
#
#        [[-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.0126553 ,  0.01534278, -0.03871063, -0.04987437,
#           0.02977861, -0.03553314, -0.00416569, -0.01277151,
#          -0.04292266,  0.04102322],
#         [-0.03033017,  0.0220539 ,  0.04938984, -0.01309539,
#           0.00350443,  0.01133143, -0.04417115, -0.00655508,
#           0.00018213, -0.02144477],
#         [ 0.01389608,  0.01005043, -0.01167576, -0.03750848,
#           0.02761997,  0.01979787, -0.01873717,  0.00797687,
#           0.030223  , -0.03977693],
#         [-0.00396502,  0.00770275,  0.00732481, -0.01204047,
#          -0.04001433,  0.00302528, -0.0175334 ,  0.03143207,
#           0.00956482, -0.04212653],
#         [-0.04403033,  0.02228909,  0.03955319, -0.03440046,
#           0.03757701, -0.03162825, -0.03258059, -0.02057334,
#          -0.01892244, -0.03917055]],
#
#        [[-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.00432414, -0.03757532,  0.04680395, -0.00845687,
#           0.03159577, -0.02176113, -0.00886682,  0.00304248,
#          -0.00300078,  0.0382336 ],
#         [ 0.02947653,  0.02852466,  0.02064506, -0.00574272,
#           0.04779477, -0.04508482, -0.0359484 , -0.03446455,
#           0.04430174, -0.01418214],
#         [-0.03942776,  0.04618042, -0.00829417,  0.04930958,
#           0.01490195,  0.02654774,  0.03497565,  0.02525297,
#           0.02923616,  0.01034783],
#         [ 0.01732167,  0.01659891, -0.03761937, -0.00788709,
#          -0.0014287 ,  0.01733841, -0.03760829, -0.00587931,
#          -0.03877031, -0.03142788],
#         [-0.03566317,  0.02118883, -0.02694107, -0.00496116,
#          -0.00107721,  0.0384548 , -0.04311615, -0.03296349,
#          -0.0228699 , -0.03029678]],
#
#        [[-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [-0.03167697, -0.01129351,  0.01975479, -0.0387794 ,
#          -0.01568038,  0.02628534,  0.00924586,  0.03356769,
#           0.02589274, -0.0309998 ],
#         [ 0.0403085 ,  0.04018803, -0.00550437, -0.00893164,
#          -0.00917149, -0.04089105, -0.03148741, -0.03844877,
#          -0.00869063, -0.03456775],
#         [ 0.00934645, -0.01840673,  0.02168819, -0.03441292,
#          -0.00889671, -0.00765915,  0.02149323, -0.01725854,
#           0.01975003, -0.0327628 ],
#         [ 0.02874908, -0.02495067,  0.02832863, -0.04100174,
#           0.02647408, -0.00717875,  0.01130608,  0.02878617,
#           0.02540835,  0.04693798],
#         [-0.00396502,  0.00770275,  0.00732481, -0.01204047,
#          -0.04001433,  0.00302528, -0.0175334 ,  0.03143207,
#           0.00956482, -0.04212653]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 6186, 6775,  637, 4895])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[ 0.01453609,  0.03697893,  0.02267558,  0.01149287, -0.03695335,
#          0.01416664,  0.03655917,  0.00734384,  0.03028754,  0.00339943],
#        [ 0.01453609,  0.03697893,  0.02267558,  0.01149287, -0.03695335,
#          0.01416664,  0.03655917,  0.00734384,  0.03028754,  0.00339943],
#        [ 0.01453609,  0.03697893,  0.02267558,  0.01149287, -0.03695335,
#          0.01416664,  0.03655917,  0.00734384,  0.03028754,  0.00339943],
#        [ 0.01453609,  0.03697893,  0.02267558,  0.01149287, -0.03695335,
#          0.01416664,  0.03655917,  0.00734384,  0.03028754,  0.00339943],
#        [-0.03792738,  0.01958679, -0.04232483, -0.03475742,  0.02182527,
#          0.01143194, -0.03125288,  0.02584182,  0.0050171 ,  0.04725457],
#        [-0.02213118,  0.00730393,  0.02797868, -0.02386508, -0.0024281 ,
#          0.04419583, -0.02011771, -0.00502002, -0.03373672, -0.04126013],
#        [-0.02629154,  0.02487988, -0.02824695,  0.0302802 , -0.01835672,
#         -0.00683415,  0.01606056, -0.04426531, -0.03801771, -0.04581957],
#        [-0.01679759,  0.04462079,  0.02781102, -0.04639838,  0.0059711 ,
#          0.00940369, -0.01027383,  0.01697389, -0.01460341,  0.02758609]],
#       dtype=float32)
